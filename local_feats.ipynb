# %%
import cv2
import math
import csv
import hnswlib
from os import path
import numpy as np

# InceptionResNetV2: 1536
# DenseNet121: 1024
# Xception 2048
# ResNet50 2048
# InceptionV3
# VGG16 512
# VGG19 512
# MobileNet
# MobileNetV2
# NASNet: 4032

######################################################
from keras.applications import vgg16
from keras.applications.vgg16 import preprocess_input

feature_dimenstion = 512 
default_tile_size = 224
default_vertical_tiles = 3
default_neighbor_count = 3
######################################################

def prepare_image_paths_labels():
    labels_file = "household_images/labels.csv"
    data = genfromtxt(labels_file, delimiter=',')
    return data


def prepare_image_paths_labels():
    directory_path = "household_images/images"
    labels_file = "household_images/labels.csv"

    with open(labels_file, "rt", encoding="utf8") as f_input:
        csv_input = csv.reader(f_input)
        header = next(csv_input)
        data = [row for row in csv_input]
    
    image_paths = [path.join(directory_path, row[0]) for row in data]
    image_labels = [int(row[1]) for row in data]
    
    return image_paths, image_labels


def open_and_prepare_image(image_path, tile_size = default_tile_size, vertical_tiles = default_vertical_tiles):
    image = cv2.imread(image_path)
    
    target_height = tile_size * vertical_tiles
    scale_percent = target_height/image.shape[0]
    
    horizontal_tiles = image.shape[1] * scale_percent // tile_size
    target_width = tile_size * horizontal_tiles
    
    scale_width = math.floor(scale_percent * image.shape[1])
    
    #print("(scale_width, target_height)", (scale_width, target_height))
    image = cv2.resize(image, (scale_width, target_height), interpolation=cv2.INTER_CUBIC)
    return image


def extract_windows(image, window_size=default_tile_size, channel_count=3, interior_w=False, interior_h=False):
    
    n_cells = (image.shape[0] // window_size, image.shape[1] // window_size)

    if interior_w:
        n_cells = (n_cells[0] - 1, n_cells[1])

    if interior_h:
        n_cells = (n_cells[0], n_cells[1] - 1)

    img_shape = (n_cells[0] * window_size, n_cells[1] * window_size)

    margins = ((image.shape[0] - img_shape[0])//2, (image.shape[1] - img_shape[1])//2)

    windows = np.zeros((n_cells[0] * n_cells[1], window_size, window_size, channel_count))
    coords = np.zeros((n_cells[0] * n_cells[1], 2))

    for i in range(n_cells[0]):
        for j in range(n_cells[1]):
            img = image[(margins[0] + window_size*i):(margins[0] + window_size*(i+1)), (margins[1] + window_size*j):(margins[1] + window_size*(j+1))]
            windows[i * n_cells[1] + j] = img
            coords[i * n_cells[1] + j] = (margins[0] + window_size*i + window_size//2, margins[1] + window_size*j + window_size//2)

    return windows, coords


def convert_output(feats):
    print("feats.shape", feats.shape)
    
    reduced_feats = np.zeros((feats.shape[0]*feats.shape[1]*feats.shape[2], feats.shape[3]))

    index = 0
    for i in range(feats.shape[0]):
        for j in range(feats.shape[1]):
            for k in range(feats.shape[2]):
                reduced_feats[index] = feats[i,j,k,:]
                index += 1

    return reduced_feats


def main():
    
    ######################################################
    model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(default_tile_size, default_tile_size, 3))
    ######################################################
    
    image_paths, image_labels = prepare_image_paths_labels()
    
    image_count = len(image_paths)
    neighbor_count = default_neighbor_count
    
    descriptors = []
    labels = []
    indexes = []

    scores = []
    
    window_count = 0
    
    
    for i in range(image_count):
    
        image_path = image_paths[i]
        print(i, image_path)
    
        image = open_and_prepare_image(image_path)
        windows, coords = extract_windows(image)

        window_count = windows.shape[0]

        print("window_count", window_count)
    
        batch = np.zeros((window_count, default_tile_size, default_tile_size, 3))

        for j in range(window_count):
            batch[j] = windows[j]

        x = preprocess_input(batch)
        y = model.predict(x)
        feature = convert_output(y)

        print("feature.shape", feature.shape)
        
        for j in range(feature.shape[0]):
            descriptors.append(feature[j, :])
            labels.append(image_labels[i])
            indexes.append(i)
            
    desc_index = hnswlib.Index(space='cosine', dim=feature_dimenstion)
    desc_index.init_index(max_elements=1000000, ef_construction=500, M=32)
    desc_index.set_ef(500)    
    desc_index.add_items(np.array(descriptors), np.arange(len(descriptors)))
    
    
    for i in range(len(descriptors)):
        descriptor = descriptors[i]
        #print("descriptor.shape", descriptor.shape)
        
        idxs, distances = desc_index.knn_query(descriptor, k=neighbor_count + feature.shape[0])
        #print("idxs.shape", idxs.shape)
        #print("distances.shape", distances.shape)
        
        count = 0
        candidates = 0
        
        for j in range(len(idxs[0])):
            idx = idxs[0][j]
            #print("idx", idx)
            
            if indexes[i] == indexes[idx]:
                continue
                
            candidates += 1
            
            if labels[i] == labels[idx]:
                count += 1
                
            if candidates >= neighbor_count:
                break
        
        #print("Score", count/candidates)
        scores.append(count/candidates)
    
    return sum(scores)/len(scores)


main()
# Out:
# Using TensorFlow backend.
# 0 household_images/images/IMG_0317.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 1 household_images/images/IMG_0332.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 2 household_images/images/IMG_0333.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 3 household_images/images/IMG_0334.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 4 household_images/images/IMG_0452.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 5 household_images/images/IMG_0453.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 6 household_images/images/IMG_0454.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 7 household_images/images/IMG_0456.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 8 household_images/images/IMG_0461.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 9 household_images/images/IMG_0464.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 10 household_images/images/IMG_0465.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 11 household_images/images/IMG_0470.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 12 household_images/images/IMG_0559.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 13 household_images/images/IMG_0560.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 14 household_images/images/IMG_0585.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 15 household_images/images/IMG_0586.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 16 household_images/images/IMG_0682.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 17 household_images/images/IMG_0683.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 18 household_images/images/IMG_0685.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 19 household_images/images/IMG_0688.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 20 household_images/images/IMG_0746.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 21 household_images/images/IMG_0747.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 22 household_images/images/IMG_1035.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 23 household_images/images/IMG_1048.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 24 household_images/images/IMG_1052.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 25 household_images/images/IMG_1053.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 26 household_images/images/IMG_1054.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 27 household_images/images/IMG_1063.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 28 household_images/images/IMG_1064.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 29 household_images/images/IMG_1112.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 30 household_images/images/IMG_0331.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 31 household_images/images/IMG_0459.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 32 household_images/images/IMG_0460.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 33 household_images/images/IMG_0469.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 34 household_images/images/IMG_0557.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 35 household_images/images/IMG_0558.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 36 household_images/images/IMG_0681.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 37 household_images/images/IMG_0686.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 38 household_images/images/IMG_1046.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 39 household_images/images/IMG_1047.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 40 household_images/images/IMG_1056.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 41 household_images/images/IMG_1113.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 42 household_images/images/IMG_0179.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 43 household_images/images/IMG_0199.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 44 household_images/images/IMG_0322.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 45 household_images/images/IMG_0326.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 46 household_images/images/IMG_0457.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 47 household_images/images/IMG_0471.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 48 household_images/images/IMG_0527.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 49 household_images/images/IMG_0545.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 50 household_images/images/IMG_0556.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 51 household_images/images/IMG_0679.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 52 household_images/images/IMG_0680.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 53 household_images/images/IMG_0687.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 54 household_images/images/IMG_1049.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 55 household_images/images/IMG_1051.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 56 household_images/images/IMG_1057.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 57 household_images/images/IMG_1058.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 58 household_images/images/IMG_0175.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 59 household_images/images/IMG_0176.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 60 household_images/images/IMG_0177.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 61 household_images/images/IMG_0178.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 62 household_images/images/IMG_0318.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 63 household_images/images/IMG_0319.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 64 household_images/images/IMG_0320.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 65 household_images/images/IMG_0321.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 66 household_images/images/IMG_0451.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 67 household_images/images/IMG_0455.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 68 household_images/images/IMG_0462.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 69 household_images/images/IMG_0463.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 70 household_images/images/IMG_0531.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 71 household_images/images/IMG_0684.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 72 household_images/images/IMG_1050.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 73 household_images/images/IMG_1071.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 74 household_images/images/IMG_0180.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 75 household_images/images/IMG_0181.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 76 household_images/images/IMG_0323.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 77 household_images/images/IMG_0324.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 78 household_images/images/IMG_0325.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 79 household_images/images/IMG_0327.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 80 household_images/images/IMG_0458.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 81 household_images/images/IMG_0472.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 82 household_images/images/IMG_0473.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 83 household_images/images/IMG_0474.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 84 household_images/images/IMG_0475.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 85 household_images/images/IMG_0476.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 86 household_images/images/IMG_0480.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 87 household_images/images/IMG_0524.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 88 household_images/images/IMG_0529.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 89 household_images/images/IMG_0530.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 90 household_images/images/IMG_0672.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 91 household_images/images/IMG_0676.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 92 household_images/images/IMG_0677.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 93 household_images/images/IMG_0678.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 94 household_images/images/IMG_1036.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 95 household_images/images/IMG_1037.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 96 household_images/images/IMG_1038.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 97 household_images/images/IMG_1039.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 98 household_images/images/IMG_1059.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 99 household_images/images/IMG_1060.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 100 household_images/images/IMG_0513.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 101 household_images/images/IMG_0514.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 102 household_images/images/IMG_0515.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 103 household_images/images/IMG_0516.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 104 household_images/images/IMG_0517.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 105 household_images/images/IMG_0518.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 106 household_images/images/IMG_0519.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 107 household_images/images/IMG_0520.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 108 household_images/images/IMG_0521.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 109 household_images/images/IMG_0522.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 110 household_images/images/IMG_0523.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 111 household_images/images/IMG_0549.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 112 household_images/images/IMG_0656.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 113 household_images/images/IMG_0657.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 114 household_images/images/IMG_0658.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 115 household_images/images/IMG_0673.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 116 household_images/images/IMG_0674.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 117 household_images/images/IMG_0675.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 118 household_images/images/IMG_1040.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 119 household_images/images/IMG_0182.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 120 household_images/images/IMG_0196.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 121 household_images/images/IMG_0197.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 122 household_images/images/IMG_0198.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 123 household_images/images/IMG_0328.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 124 household_images/images/IMG_0477.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 125 household_images/images/IMG_0478.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 126 household_images/images/IMG_0479.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 127 household_images/images/IMG_0485.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 128 household_images/images/IMG_0486.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 129 household_images/images/IMG_0505.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 130 household_images/images/IMG_0506.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 131 household_images/images/IMG_0511.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 132 household_images/images/IMG_0512.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 133 household_images/images/IMG_0525.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 134 household_images/images/IMG_0587.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 135 household_images/images/IMG_0642.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 136 household_images/images/IMG_0643.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 137 household_images/images/IMG_0655.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 138 household_images/images/IMG_0659.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 139 household_images/images/IMG_0660.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 140 household_images/images/IMG_0663.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 141 household_images/images/IMG_0664.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 142 household_images/images/IMG_0665.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 143 household_images/images/IMG_0670.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 144 household_images/images/IMG_0748.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 145 household_images/images/IMG_0749.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 146 household_images/images/IMG_1029.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 147 household_images/images/IMG_1041.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 148 household_images/images/IMG_1042.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 149 household_images/images/IMG_1125.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 150 household_images/images/IMG_0183.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 151 household_images/images/IMG_0184.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 152 household_images/images/IMG_0185.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 153 household_images/images/IMG_0186.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 154 household_images/images/IMG_0187.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 155 household_images/images/IMG_0200.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 156 household_images/images/IMG_0201.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 157 household_images/images/IMG_0329.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 158 household_images/images/IMG_0330.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 159 household_images/images/IMG_0466.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 160 household_images/images/IMG_0467.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 161 household_images/images/IMG_0468.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 162 household_images/images/IMG_0487.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 163 household_images/images/IMG_0488.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 164 household_images/images/IMG_0494.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 165 household_images/images/IMG_0526.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 166 household_images/images/IMG_0528.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 167 household_images/images/IMG_0544.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 168 household_images/images/IMG_0554.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 169 household_images/images/IMG_0555.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 170 household_images/images/IMG_0668.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 171 household_images/images/IMG_0669.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 172 household_images/images/IMG_0671.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 173 household_images/images/IMG_1033.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 174 household_images/images/IMG_1034.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 175 household_images/images/IMG_1043.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 176 household_images/images/IMG_1044.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 177 household_images/images/IMG_1045.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 178 household_images/images/IMG_0496.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 179 household_images/images/IMG_0497.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 180 household_images/images/IMG_0498.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 181 household_images/images/IMG_0499.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 182 household_images/images/IMG_0500.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 183 household_images/images/IMG_0501.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 184 household_images/images/IMG_0502.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 185 household_images/images/IMG_0503.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 186 household_images/images/IMG_0504.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 187 household_images/images/IMG_0508.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 188 household_images/images/IMG_0510.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 189 household_images/images/IMG_0546.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 190 household_images/images/IMG_0547.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 191 household_images/images/IMG_0548.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 192 household_images/images/IMG_0550.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 193 household_images/images/IMG_0644.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 194 household_images/images/IMG_0645.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 195 household_images/images/IMG_0646.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 196 household_images/images/IMG_0647.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 197 household_images/images/IMG_0648.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 198 household_images/images/IMG_0649.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 199 household_images/images/IMG_0650.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 200 household_images/images/IMG_1021.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 201 household_images/images/IMG_1022.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 202 household_images/images/IMG_1023.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 203 household_images/images/IMG_1024.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 204 household_images/images/IMG_1025.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 205 household_images/images/IMG_1030.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 206 household_images/images/IMG_1115.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 207 household_images/images/IMG_1117.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 208 household_images/images/IMG_1118.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 209 household_images/images/IMG_1119.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 210 household_images/images/IMG_1120.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 211 household_images/images/IMG_1121.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 212 household_images/images/IMG_1122.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 213 household_images/images/IMG_1123.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 214 household_images/images/IMG_1124.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 215 household_images/images/IMG_1126.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 216 household_images/images/IMG_1127.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 217 household_images/images/IMG_1128.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 218 household_images/images/IMG_0188.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 219 household_images/images/IMG_0202.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 220 household_images/images/IMG_0203.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 221 household_images/images/IMG_0204.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 222 household_images/images/IMG_0205.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 223 household_images/images/IMG_0489.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 224 household_images/images/IMG_0490.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 225 household_images/images/IMG_0543.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 226 household_images/images/IMG_0667.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 227 household_images/images/IMG_1013.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 228 household_images/images/IMG_1014.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 229 household_images/images/IMG_1032.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 230 household_images/images/IMG_0189.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 231 household_images/images/IMG_0190.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 232 household_images/images/IMG_0195.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 233 household_images/images/IMG_0481.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 234 household_images/images/IMG_0482.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 235 household_images/images/IMG_0483.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 236 household_images/images/IMG_0484.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 237 household_images/images/IMG_0552.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 238 household_images/images/IMG_0641.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 239 household_images/images/IMG_0661.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 240 household_images/images/IMG_0662.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 241 household_images/images/IMG_1008.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 242 household_images/images/IMG_1009.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 243 household_images/images/IMG_1012.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 244 household_images/images/IMG_1020.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 245 household_images/images/IMG_1027.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 246 household_images/images/IMG_1028.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 247 household_images/images/IMG_1031.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 248 household_images/images/IMG_1114.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 249 household_images/images/IMG_0192.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 250 household_images/images/IMG_0193.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 251 household_images/images/IMG_0491.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 252 household_images/images/IMG_0492.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 253 household_images/images/IMG_0542.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 254 household_images/images/IMG_0553.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 255 household_images/images/IMG_0666.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 256 household_images/images/IMG_1011.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 257 household_images/images/IMG_1015.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 258 household_images/images/IMG_1016.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 259 household_images/images/IMG_0191.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 260 household_images/images/IMG_0194.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 261 household_images/images/IMG_0493.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 262 household_images/images/IMG_0495.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 263 household_images/images/IMG_0507.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 264 household_images/images/IMG_0509.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 265 household_images/images/IMG_0551.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 266 household_images/images/IMG_0640.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 267 household_images/images/IMG_0651.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 268 household_images/images/IMG_0652.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 269 household_images/images/IMG_0653.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 270 household_images/images/IMG_0654.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 271 household_images/images/IMG_1017.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 272 household_images/images/IMG_1018.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 273 household_images/images/IMG_1019.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 274 household_images/images/IMG_1026.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 275 household_images/images/IMG_0208.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 276 household_images/images/IMG_0209.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 277 household_images/images/IMG_0219.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 278 household_images/images/IMG_0234.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 279 household_images/images/IMG_0235.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 280 household_images/images/IMG_0236.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 281 household_images/images/IMG_0237.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 282 household_images/images/IMG_0239.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 283 household_images/images/IMG_0250.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 284 household_images/images/IMG_0361.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 285 household_images/images/IMG_0362.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 286 household_images/images/IMG_0384.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 287 household_images/images/IMG_0606.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 288 household_images/images/IMG_0618.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 289 household_images/images/IMG_0619.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 290 household_images/images/IMG_0953.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 291 household_images/images/IMG_0954.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 292 household_images/images/IMG_0955.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 293 household_images/images/IMG_0973.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 294 household_images/images/IMG_0974.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 295 household_images/images/IMG_0980.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 296 household_images/images/IMG_1007.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 297 household_images/images/IMG_0279.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 298 household_images/images/IMG_0280.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 299 household_images/images/IMG_0311.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 300 household_images/images/IMG_0312.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 301 household_images/images/IMG_0313.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 302 household_images/images/IMG_0314.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 303 household_images/images/IMG_0315.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 304 household_images/images/IMG_0316.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 305 household_images/images/IMG_0399.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 306 household_images/images/IMG_0400.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 307 household_images/images/IMG_0402.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 308 household_images/images/IMG_0403.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 309 household_images/images/IMG_0449.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 310 household_images/images/IMG_0450.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 311 household_images/images/IMG_0561.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 312 household_images/images/IMG_0562.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 313 household_images/images/IMG_0563.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 314 household_images/images/IMG_0689.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 315 household_images/images/IMG_0690.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 316 household_images/images/IMG_0691.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 317 household_images/images/IMG_0744.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 318 household_images/images/IMG_0745.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 319 household_images/images/IMG_1055.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 320 household_images/images/IMG_1061.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 321 household_images/images/IMG_1062.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 322 household_images/images/IMG_1068.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 323 household_images/images/IMG_1069.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 324 household_images/images/IMG_1070.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 325 household_images/images/IMG_1082.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 326 household_images/images/IMG_1110.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 327 household_images/images/IMG_1111.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 328 household_images/images/IMG_0206.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 329 household_images/images/IMG_0207.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 330 household_images/images/IMG_0222.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 331 household_images/images/IMG_0223.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 332 household_images/images/IMG_0224.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 333 household_images/images/IMG_0229.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 334 household_images/images/IMG_0230.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 335 household_images/images/IMG_0231.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 336 household_images/images/IMG_0232.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 337 household_images/images/IMG_0233.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 338 household_images/images/IMG_0242.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 339 household_images/images/IMG_0363.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 340 household_images/images/IMG_0364.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 341 household_images/images/IMG_0385.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 342 household_images/images/IMG_0386.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 343 household_images/images/IMG_0532.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 344 household_images/images/IMG_0534.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 345 household_images/images/IMG_0535.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 346 household_images/images/IMG_0536.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 347 household_images/images/IMG_0600.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 348 household_images/images/IMG_0601.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 349 household_images/images/IMG_0602.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 350 household_images/images/IMG_0603.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 351 household_images/images/IMG_0604.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 352 household_images/images/IMG_0605.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 353 household_images/images/IMG_0607.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 354 household_images/images/IMG_0633.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 355 household_images/images/IMG_0634.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 356 household_images/images/IMG_0635.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 357 household_images/images/IMG_0636.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 358 household_images/images/IMG_0637.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 359 household_images/images/IMG_0638.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 360 household_images/images/IMG_0639.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 361 household_images/images/IMG_0956.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 362 household_images/images/IMG_0957.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 363 household_images/images/IMG_0958.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 364 household_images/images/IMG_0959.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 365 household_images/images/IMG_0964.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 366 household_images/images/IMG_0965.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 367 household_images/images/IMG_0984.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 368 household_images/images/IMG_0985.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 369 household_images/images/IMG_0996.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 370 household_images/images/IMG_0998.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 371 household_images/images/IMG_0999.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 372 household_images/images/IMG_1001.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 373 household_images/images/IMG_0214.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 374 household_images/images/IMG_0225.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 375 household_images/images/IMG_0248.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 376 household_images/images/IMG_0249.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 377 household_images/images/IMG_0251.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 378 household_images/images/IMG_0358.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 379 household_images/images/IMG_0359.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 380 household_images/images/IMG_0360.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 381 household_images/images/IMG_0369.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 382 household_images/images/IMG_0370.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 383 household_images/images/IMG_0371.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 384 household_images/images/IMG_0380.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 385 household_images/images/IMG_0381.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 386 household_images/images/IMG_0620.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 387 household_images/images/IMG_0621.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 388 household_images/images/IMG_0632.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 389 household_images/images/IMG_0952.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 390 household_images/images/IMG_0970.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 391 household_images/images/IMG_0971.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 392 household_images/images/IMG_0972.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 393 household_images/images/IMG_0983.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 394 household_images/images/IMG_0220.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 395 household_images/images/IMG_0221.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 396 household_images/images/IMG_0226.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 397 household_images/images/IMG_0246.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 398 household_images/images/IMG_0247.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 399 household_images/images/IMG_0258.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 400 household_images/images/IMG_0259.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 401 household_images/images/IMG_0355.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 402 household_images/images/IMG_0356.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 403 household_images/images/IMG_0357.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 404 household_images/images/IMG_0382.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 405 household_images/images/IMG_0383.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 406 household_images/images/IMG_0622.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 407 household_images/images/IMG_0623.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 408 household_images/images/IMG_0624.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 409 household_images/images/IMG_0625.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 410 household_images/images/IMG_0967.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 411 household_images/images/IMG_0968.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 412 household_images/images/IMG_0969.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 413 household_images/images/IMG_0982.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 414 household_images/images/IMG_0243.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 415 household_images/images/IMG_0336.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 416 household_images/images/IMG_0533.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 417 household_images/images/IMG_0608.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 418 household_images/images/IMG_0609.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 419 household_images/images/IMG_0215.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 420 household_images/images/IMG_0244.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 421 household_images/images/IMG_0245.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 422 household_images/images/IMG_0252.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 423 household_images/images/IMG_0253.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 424 household_images/images/IMG_0254.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 425 household_images/images/IMG_0255.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 426 household_images/images/IMG_0256.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 427 household_images/images/IMG_0257.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 428 household_images/images/IMG_0345.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 429 household_images/images/IMG_0346.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 430 household_images/images/IMG_0347.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 431 household_images/images/IMG_0348.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 432 household_images/images/IMG_0349.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 433 household_images/images/IMG_0350.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 434 household_images/images/IMG_0351.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 435 household_images/images/IMG_0352.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 436 household_images/images/IMG_0372.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# ...
# feature.shape (588, 512)
# 610 household_images/images/IMG_0411.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 611 household_images/images/IMG_0412.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 612 household_images/images/IMG_0425.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 613 household_images/images/IMG_0426.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 614 household_images/images/IMG_0427.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 615 household_images/images/IMG_0428.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 616 household_images/images/IMG_0429.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 617 household_images/images/IMG_0568.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 618 household_images/images/IMG_0572.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 619 household_images/images/IMG_0580.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 620 household_images/images/IMG_0581.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 621 household_images/images/IMG_0705.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 622 household_images/images/IMG_0714.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 623 household_images/images/IMG_0715.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 624 household_images/images/IMG_0718.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 625 household_images/images/IMG_0728.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 626 household_images/images/IMG_0729.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 627 household_images/images/IMG_1076.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 628 household_images/images/IMG_1085.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 629 household_images/images/IMG_1088.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 630 household_images/images/IMG_1089.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 631 household_images/images/IMG_1102.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 632 household_images/images/IMG_1103.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 633 household_images/images/IMG_1104.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 634 household_images/images/IMG_1105.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 635 household_images/images/IMG_0271.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 636 household_images/images/IMG_0272.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 637 household_images/images/IMG_0273.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 638 household_images/images/IMG_0274.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 639 household_images/images/IMG_0275.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 640 household_images/images/IMG_0276.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 641 household_images/images/IMG_0281.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 642 household_images/images/IMG_0282.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 643 household_images/images/IMG_0283.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 644 household_images/images/IMG_0284.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 645 household_images/images/IMG_0285.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 646 household_images/images/IMG_0286.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 647 household_images/images/IMG_0293.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 648 household_images/images/IMG_0294.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 649 household_images/images/IMG_0295.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 650 household_images/images/IMG_0296.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 651 household_images/images/IMG_0297.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 652 household_images/images/IMG_0298.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 653 household_images/images/IMG_0310.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 654 household_images/images/IMG_0387.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 655 household_images/images/IMG_0388.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 656 household_images/images/IMG_0389.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 657 household_images/images/IMG_0390.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 658 household_images/images/IMG_0401.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 659 household_images/images/IMG_0404.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 660 household_images/images/IMG_0405.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 661 household_images/images/IMG_0406.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 662 household_images/images/IMG_0407.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 663 household_images/images/IMG_0413.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 664 household_images/images/IMG_0418.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 665 household_images/images/IMG_0419.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 666 household_images/images/IMG_0420.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 667 household_images/images/IMG_0421.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 668 household_images/images/IMG_0422.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 669 household_images/images/IMG_0430.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 670 household_images/images/IMG_0565.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 671 household_images/images/IMG_0566.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 672 household_images/images/IMG_0569.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 673 household_images/images/IMG_0570.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 674 household_images/images/IMG_0571.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 675 household_images/images/IMG_0696.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 676 household_images/images/IMG_0697.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 677 household_images/images/IMG_0698.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 678 household_images/images/IMG_0699.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 679 household_images/images/IMG_0700.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 680 household_images/images/IMG_0701.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 681 household_images/images/IMG_0702.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 682 household_images/images/IMG_0710.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 683 household_images/images/IMG_0711.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 684 household_images/images/IMG_0712.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 685 household_images/images/IMG_0713.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 686 household_images/images/IMG_0716.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 687 household_images/images/IMG_0723.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 688 household_images/images/IMG_0724.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 689 household_images/images/IMG_0725.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 690 household_images/images/IMG_0737.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 691 household_images/images/IMG_0738.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 692 household_images/images/IMG_0739.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 693 household_images/images/IMG_1072.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 694 household_images/images/IMG_1073.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 695 household_images/images/IMG_1074.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 696 household_images/images/IMG_1077.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 697 household_images/images/IMG_1078.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 698 household_images/images/IMG_1079.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 699 household_images/images/IMG_1080.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 700 household_images/images/IMG_1081.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 701 household_images/images/IMG_1090.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 702 household_images/images/IMG_1091.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 703 household_images/images/IMG_1097.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 704 household_images/images/IMG_1098.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 705 household_images/images/IMG_1099.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 706 household_images/images/IMG_1100.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 707 household_images/images/IMG_1101.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 708 household_images/images/IMG_1106.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 709 household_images/images/IMG_1107.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 710 household_images/images/IMG_1108.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 711 household_images/images/IMG_1109.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 712 household_images/images/IMG_0277.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 713 household_images/images/IMG_0289.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 714 household_images/images/IMG_0290.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 715 household_images/images/IMG_0291.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 716 household_images/images/IMG_0292.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 717 household_images/images/IMG_0397.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 718 household_images/images/IMG_0398.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 719 household_images/images/IMG_0408.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 720 household_images/images/IMG_0409.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 721 household_images/images/IMG_0417.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 722 household_images/images/IMG_0564.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 723 household_images/images/IMG_0567.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 724 household_images/images/IMG_0584.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 725 household_images/images/IMG_0694.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 726 household_images/images/IMG_0695.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 727 household_images/images/IMG_0703.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 728 household_images/images/IMG_0704.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 729 household_images/images/IMG_0730.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 730 household_images/images/IMG_0731.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 731 household_images/images/IMG_0732.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 732 household_images/images/IMG_0733.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 733 household_images/images/IMG_0734.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 734 household_images/images/IMG_0735.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 735 household_images/images/IMG_0736.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 736 household_images/images/IMG_0743.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 737 household_images/images/IMG_1066.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 738 household_images/images/IMG_1067.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 739 household_images/images/IMG_0278.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 740 household_images/images/IMG_0395.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 741 household_images/images/IMG_0396.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 742 household_images/images/IMG_0414.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 743 household_images/images/IMG_0415.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 744 household_images/images/IMG_0416.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 745 household_images/images/IMG_0582.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 746 household_images/images/IMG_0583.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 747 household_images/images/IMG_0692.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 748 household_images/images/IMG_0693.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 749 household_images/images/IMG_0717.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 750 household_images/images/IMG_0740.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 751 household_images/images/IMG_0741.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 752 household_images/images/IMG_0742.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 753 household_images/images/IMG_1065.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 754 household_images/images/IMG_1083.jpg
# window_count 12
# feats.shape (12, 7, 7, 512)
# feature.shape (588, 512)
# 0.3110097460616839
