# %% [markdown]
# ## Evaluation of Convolutional Features for Nearest Neighbor Performance on Household Scene Recognition
# For each image break into k patches. Generate convolutional features for each patch. For each patch find n nearest neighbors. Discard nearest neighbors that originate from the same image. For each patch calculate the score s which is the percent of n neighbors that have the same label. The overall score is the sum of the individual patch scored divided by the total number of pataches.
#
# Evaluate the overall scores for different pretrained conv nets using different patch sizes and arrangments.

# %% [markdown]
# Sandbox Code

# %%
typeof(sq_net)

# %%
sq_net

# %%
sq_net.layers

# %%
sq_net.layers[0]

# %%
?names

# %%
fieldnames(sq_net.layers)

# %%
sq_net.layers[1]

# %%
x = rand(Float32, 224, 224, 3, 1)

# %%
sq_net(x)

# %%
sq_net(rand(Float32, 120, 120, 3, 1))

# %%
size(sq_net.weights)

# %%
sq_net.layers[1].weights

# %%
weight = Metalhead.weights("squeezenet.bson")

# %%
size(weight[:conv1_b_0])

# %%
for ele in keys(weight)
    println(ele)
  end

# %%
sq_net.layers[1:35](rand(Float32, 224, 224, 3, 1))

# %%
sq_net.layers[1:33](rand(Float32, 224, 224, 3, 1))

# %%
sq_net.layers[35]

# %%
sq_net.layers[34]

# %%
sq_net.layers[32]

# %%
sq_net.layers[33]

# %%
sq_net.layers[1:32](rand(Float32, 224, 224, 3, 1))

# %%
des = sq_net.layers[1:32](rand(Float32, 224, 224, 3, 1))

# %%
des[1,1,1,1]

# %%
des = sq_net.layers[1:32](rand(Float32, 224, 224, 3, 1))

# %%
des = sq_net.layers[1:35](rand(Float32, 224, 224, 3, 1))

# %%
sq_net.layers[33]

# %%
des = sq_net.layers[35]

# %%
using Pkg
Pkg.clone("https://github.com/JuliaNeighbors/HNSW.jl.git")

# %%
using HNSW

# %%
rand(2)

# %%
data = [[0,0],[0,1]]
typeof(data)

# %%
data

# %%
hnsw = HierarchicalNSW(data; efConstruction=100, M=16, ef=50)

# %%
add_to_graph!(hnsw)

# %%
idxs, dists = knn_search(hnsw, [[0,0]], 2)

# %%
data = [[0.0,0.0],[10.0,10.0]]

# %%
hnsw = HierarchicalNSW(data; efConstruction=100, M=16, ef=50)

# %%
add_to_graph!(hnsw)

# %%
idxs, dists = knn_search(hnsw, [[0,0]], 3)

# %%
size(data)

# %%
image = load("household_images/images/IMG_0317.jpg");

# %%
size(image)

# %%
fld(9,2)

# %%
show(window[1,1,1])

# %%
a = [1,1,1]

# %%
a += [1,1,1]

# %%
using Metalhead
model = VGG19()
model_layers = model.layers[1:21]
y = model_layers(rand(Float32, 224, 224, 3, 1))

d = zeros(Float32, 512)

for i in 1:size(y)[1]
    for j in 1:size(y)[2]
        d += reshape(y[i,j,:], (512,))
    end
end

d /= (size(y)[1] * size(y)[2])
# des = sq_net.layers[1:35](rand(Float32, 224, 224, 3, 1))

# %%
using Metalhead
model = GoogleNet()
model_layers = model.layers[1:18]
y = model_layers(rand(Float64, 224, 224, 3, 1))
show(typeof(y))
size(y)

# d = zeros(Float32, 512)

# for i in 1:size(y)[1]
#     for j in 1:size(y)[2]
#         d += reshape(y[i,j,:], (512,))
#     end
# end

# d /= (size(y)[1] * size(y)[2])
# des = sq_net.layers[1:35](rand(Float32, 224, 224, 3, 1))

# %% [markdown]
# # VGG19

# %%
using Images, Metalhead, HNSW, DelimitedFiles

function load_and_prepare_image(image_path)
    image = load(image_path);
    
    target_height = 224
    target_width = 224

    scale_percent = target_height/size(image)[1]
    scale_width = Int(floor(scale_percent*size(image)[2]))
    resized_image = imresize(image, (224, scale_width))

    margin_left = Int(fld(scale_width - target_width, 2))

    window = view(resized_image, :, margin_left+1:margin_left+target_width)
    
    return window
end

function convert_window(window)
    img = permutedims(Float32.(channelview(window)), (3, 2, 1));
    img[:, :, :] .*= 256.0;
    img[:, :, :] .-= 128.;
    img[:, :, :] ./= 128.;
end

function convert_output(y)
    d = zeros(Float32, 512)

    for i in 1:size(y)[1]
        for j in 1:size(y)[2]
            d += reshape(y[i,j,:], (512,))
        end
    end

    return d /= (size(y)[1] * size(y)[2])    
end

function prep_model_layers()
    model = VGG19()
    return model.layers[1:21]
end

function prepare_image_paths_labels()
    labels_file = "household_images/labels.csv"
    data = DelimitedFiles.readdlm(labels_file, ',', header=true)[1]

    directory_path = "household_images/images"
    image_paths = [joinpath(directory_path, data[y, 1]) for y in 1:size(data)[1]]
    image_labels = [data[y, 2] for y in 1:size(data)[1]]
    
    return image_paths, image_labels
end

function main()
   
    model_layers = prep_model_layers()
    
    image_paths, image_labels = prepare_image_paths_labels()

    image_count = size(image_paths)[1]
    window_count = 1
    neighbor_count = 3
    
    descriptors = []
    labels = []
    indexes = []

    scores = []
    
    # build a dict of descritor index to image index
    
    for i in 1:image_count
        
        image_path = image_paths[i]
        
        println(i, " ", image_path)
        
        window = load_and_prepare_image(image_path)
        
        batch = zeros(Float32, 224, 224, 3, window_count)
        
        batch[:,:,:,1] = convert_window(window)

        #batch[:,:,:,1] = rand(Float32, 224, 224, 3)
        
        y = model_layers(batch)
        des = convert_output(y)
        
        push!(descriptors, des)
        push!(labels, image_labels[i])
        push!(indexes, i)
    
    end
    
    hnsw = HierarchicalNSW(descriptors; efConstruction=100, M=16, ef=50)
    add_to_graph!(hnsw)
    
    # for each descriptor find neighbors, enouph to usually include all candidates
    for i in 1:size(descriptors)[1]
        idxs, dists = knn_search(hnsw, descriptors[i], neighbor_count + window_count)
        
        # find neighbor_count number of candidates and count how many of those belong to the same label
        
        count = 0
        candidates = 0
        
        for j in 1:size(idxs)[1]
            idx = idxs[j]
            
            # if neighbor belongs to same picture, it is not a candidate
            if indexes[i] == indexes[idx]
                continue
            end
            
            # this is a candidate
            
            candidates += 1
            
            # if neighbor has same label
            
            if labels[i] == labels[idx]
                count += 1
            end
            
            if candidates >= neighbor_count
                break
            end
        end
        
        println("Score: ", count/candidates)
        
        push!(scores, count/candidates)
        
    end
    
    return sum(scores)/size(scores)[1], scores
end

main()

# %% [markdown]
# # ResNet50

# %%
using Images, Metalhead, HNSW, DelimitedFiles, Flux.Tracker

function load_and_prepare_image(image_path)
    image = load(image_path);
    
    target_height = 224
    target_width = 224

    scale_percent = target_height/size(image)[1]
    scale_width = Int(floor(scale_percent*size(image)[2]))
    resized_image = imresize(image, (224, scale_width))

    margin_left = Int(fld(scale_width - target_width, 2))

    window = view(resized_image, :, margin_left+1:margin_left+target_width)
    
    return window
end

function convert_window(window)
    img = permutedims(Float64.(channelview(window)), (3, 2, 1));
    img[:, :, :] .*= 256.0;
    img[:, :, :] .-= 128.;
    img[:, :, :] ./= 128.;
end

function convert_output(y)
    a = Tracker.data(y)
    b = reshape(a, (2048,))
    return b
end

function prep_model_layers()
    model = ResNet()
    return model.layers[1:20]
end

function prepare_image_paths_labels()
    labels_file = "household_images/labels.csv"
    data = DelimitedFiles.readdlm(labels_file, ',', header=true)[1]

    directory_path = "household_images/images"
    image_paths = [joinpath(directory_path, data[y, 1]) for y in 1:size(data)[1]]
    image_labels = [data[y, 2] for y in 1:size(data)[1]]
    
    return image_paths, image_labels
end

function main()
   
    model_layers = prep_model_layers()
    
    image_paths, image_labels = prepare_image_paths_labels()

    image_count = size(image_paths)[1]
    window_count = 1
    neighbor_count = 3
    
    descriptors = []
    labels = []
    indexes = []

    scores = []
    
    # build a dict of descritor index to image index
    
    for i in 1:image_count
        
        image_path = image_paths[i]
        
        println(i, " ", image_path)
        
        window = load_and_prepare_image(image_path)
        
        batch = zeros(Float64, 224, 224, 3, window_count)
        
        batch[:,:,:,1] = convert_window(window)

        #batch[:,:,:,1] = rand(Float64, 224, 224, 3)
        
        y = model_layers(batch)
        des = convert_output(y)
        
        push!(descriptors, des)
        push!(labels, image_labels[i])
        push!(indexes, i)
    
    end
    
    hnsw = HierarchicalNSW(descriptors; efConstruction=100, M=16, ef=50)
    add_to_graph!(hnsw)
    
    # for each descriptor find neighbors, enouph to usually include all candidates
    for i in 1:size(descriptors)[1]
        idxs, dists = knn_search(hnsw, descriptors[i], neighbor_count + window_count)
        
        # find neighbor_count number of candidates and count how many of those belong to the same label
        
        count = 0
        candidates = 0
        
        for j in 1:size(idxs)[1]
            idx = idxs[j]
            
            # if neighbor belongs to same picture, it is not a candidate
            if indexes[i] == indexes[idx]
                continue
            end
            
            # this is a candidate
            
            candidates += 1
            
            # if neighbor has same label
            
            if labels[i] == labels[idx]
                count += 1
            end
            
            if candidates >= neighbor_count
                break
            end
        end
        
        println("Score: ", count/candidates)
        
        push!(scores, count/candidates)
        
    end
    
    return sum(scores)/size(scores)[1], scores
end

main()

# %% [markdown]
# ## Scores for Random Data
# 0.04370860927152313
# 0.03487858719646797
# 0.04591611479028694
# 0.034437086092715216
# 0.05209713024282561

# %% [markdown]
# ## Scores for Image Data
#
# ### VGG19 - Layers 1:21
#
# #### Whole Image (1 Patch)
#
# 3 Nearest Neighbors
# 0.5863134657836648
#
#
# ### Squeeze Net - Layers 1:35
#
# #### Whole Image (1 Patch)
#
# 3 Nearest Neighbors
# 0.1580573951434876
#
# 7 Nearest Neighbors
# 0.12128666035950819
#
#
# ### ResNet50
#
# #### Whole Image (1 Patch)
#
# 3 Nearest Neighbors
# 0.16997792494481195
#
#
# ### GoogleNet
#
# #### Whole Image (1 Patch)
#
# 3 Nearest Neighbors
# 0.21986754966887403
#
# #### Whole Image (12 Patch)
#
# 3 Nearest Neighbors
# 0.16401766004414994

# %% [markdown]
# # GoogleNet

# %%
using Images, Metalhead, HNSW, DelimitedFiles, Flux.Tracker

function load_and_prepare_image(image_path)
    image = load(image_path);
    
    tile_size = 224
    vertical_tiles = 2
    
    target_height = tile_size * vertical_tiles
    scale_percent = target_height/size(image)[1]
    
    horizontal_tiles = Int(fld(size(image)[2] * scale_percent, tile_size))
    target_width = tile_size * horizontal_tiles
    
    scale_width = Int(floor(scale_percent*size(image)[2]))
    resized_image = imresize(image, (target_height, scale_width))

    margin_left = Int(fld(scale_width - target_width, 2))

    windows = []
    
    for i in 1:vertical_tiles
        for j in 1:horizontal_tiles
            window = view(resized_image, ((i-1)*tile_size+1):(i*tile_size), (margin_left+(j-1)*tile_size+1):(margin_left+j*tile_size))
            #println(size(window))
            push!(windows, window)
        end
    end

    return windows
end
    
function convert_window(window)
    img = permutedims(Float64.(channelview(window)), (3, 2, 1));
    img[:, :, :] .*= 256.0;
    img[:, :, :] .-= 128.;
    img[:, :, :] ./= 128.;
end

function convert_output(y)
    a = Tracker.data(y)
    b = permutedims(a, (2, 1));
    return b
end

function prep_model_layers()
    model = GoogleNet()
    return model.layers[1:18]
end

function prepare_image_paths_labels()
    labels_file = "household_images/labels.csv"
    data = DelimitedFiles.readdlm(labels_file, ',', header=true)[1]

    directory_path = "household_images/images"
    image_paths = [joinpath(directory_path, data[y, 1]) for y in 1:size(data)[1]]
    image_labels = [data[y, 2] for y in 1:size(data)[1]]
    
    return image_paths, image_labels
end

function main()
   
    model_layers = prep_model_layers()
    
    image_paths, image_labels = prepare_image_paths_labels()

    image_count = size(image_paths)[1]
    neighbor_count = 3
    
    descriptors = []
    labels = []
    indexes = []

    scores = []
    
    # build a dict of descritor index to image index
    
    window_count = 0
    
    for i in 1:image_count
        
        image_path = image_paths[i]
        
        println(i, " ", image_path)
        
        windows = load_and_prepare_image(image_path)
        
        window_count = size(windows)[1]
        
        batch = zeros(Float64, 224, 224, 3, window_count)
        
        for j in 1:window_count
            batch[:,:,:,j] = convert_window(windows[j])
        end
        
        #batch[:,:,:,1] = rand(Float64, 224, 224, 3)

        y = model_layers(batch)
        des = convert_output(y)

        for j in 1:window_count
            push!(descriptors, des[j, :])
            push!(labels, image_labels[i])
            push!(indexes, i)
        end
    
    end
    
    hnsw = HierarchicalNSW(descriptors; efConstruction=100, M=16, ef=50)
    add_to_graph!(hnsw)
    
    # for each descriptor find neighbors, enouph to usually include all candidates
    for i in 1:size(descriptors)[1]
        idxs, dists = knn_search(hnsw, descriptors[i], neighbor_count + window_count)
        
        # find neighbor_count number of candidates and count how many of those belong to the same label
        
        count = 0
        candidates = 0
        
        for j in 1:size(idxs)[1]
            idx = idxs[j]
            
            # if neighbor belongs to same picture, it is not a candidate
            if indexes[i] == indexes[idx]
                continue
            end
            
            # this is a candidate
            
            candidates += 1
            
            # if neighbor has same label
            
            if labels[i] == labels[idx]
                count += 1
            end
            
            if candidates >= neighbor_count
                break
            end
        end
        
        println("Score: ", count/candidates)
        
        push!(scores, count/candidates)
        
    end
    
    return sum(scores)/size(scores)[1], scores
end

main()
# Out:
# 1 household_images/images/IMG_0317.jpg
# 2 household_images/images/IMG_0332.jpg
# 3 household_images/images/IMG_0333.jpg
# 4 household_images/images/IMG_0334.jpg
# 5 household_images/images/IMG_0452.jpg
# 6 household_images/images/IMG_0453.jpg
# 7 household_images/images/IMG_0454.jpg
# 8 household_images/images/IMG_0456.jpg
# 9 household_images/images/IMG_0461.jpg
# 10 household_images/images/IMG_0464.jpg
# 11 household_images/images/IMG_0465.jpg
# 12 household_images/images/IMG_0470.jpg
# 13 household_images/images/IMG_0559.jpg
# 14 household_images/images/IMG_0560.jpg
# 15 household_images/images/IMG_0585.jpg
# 16 household_images/images/IMG_0586.jpg
# 17 household_images/images/IMG_0682.jpg
# 18 household_images/images/IMG_0683.jpg
# 19 household_images/images/IMG_0685.jpg
# 20 household_images/images/IMG_0688.jpg
# 21 household_images/images/IMG_0746.jpg
# 22 household_images/images/IMG_0747.jpg
# 23 household_images/images/IMG_1035.jpg
# 24 household_images/images/IMG_1048.jpg
# 25 household_images/images/IMG_1052.jpg
# 26 household_images/images/IMG_1053.jpg
# 27 household_images/images/IMG_1054.jpg
# 28 household_images/images/IMG_1063.jpg
# 29 household_images/images/IMG_1064.jpg
# 30 household_images/images/IMG_1112.jpg
# 31 household_images/images/IMG_0331.jpg
# 32 household_images/images/IMG_0459.jpg
# 33 household_images/images/IMG_0460.jpg
# 34 household_images/images/IMG_0469.jpg
# 35 household_images/images/IMG_0557.jpg
# 36 household_images/images/IMG_0558.jpg
# 37 household_images/images/IMG_0681.jpg
# 38 household_images/images/IMG_0686.jpg
# 39 household_images/images/IMG_1046.jpg
# 40 household_images/images/IMG_1047.jpg
# 41 household_images/images/IMG_1056.jpg
# 42 household_images/images/IMG_1113.jpg
# 43 household_images/images/IMG_0179.jpg
# 44 household_images/images/IMG_0199.jpg
# 45 household_images/images/IMG_0322.jpg
# 46 household_images/images/IMG_0326.jpg
# 47 household_images/images/IMG_0457.jpg
# 48 household_images/images/IMG_0471.jpg
# 49 household_images/images/IMG_0527.jpg
# 50 household_images/images/IMG_0545.jpg
# 51 household_images/images/IMG_0556.jpg
# 52 household_images/images/IMG_0679.jpg
# 53 household_images/images/IMG_0680.jpg
# 54 household_images/images/IMG_0687.jpg
# 55 household_images/images/IMG_1049.jpg
# 56 household_images/images/IMG_1051.jpg
# 57 household_images/images/IMG_1057.jpg
# 58 household_images/images/IMG_1058.jpg
# 59 household_images/images/IMG_0175.jpg
# 60 household_images/images/IMG_0176.jpg
# 706 household_images/images/IMG_1099.jpg
# 707 household_images/images/IMG_1100.jpg
# 708 household_images/images/IMG_1101.jpg
# 709 household_images/images/IMG_1106.jpg
# 710 household_images/images/IMG_1107.jpg
# 711 household_images/images/IMG_1108.jpg
# 712 household_images/images/IMG_1109.jpg
# 713 household_images/images/IMG_0277.jpg
# 714 household_images/images/IMG_0289.jpg
# 715 household_images/images/IMG_0290.jpg
# 716 household_images/images/IMG_0291.jpg
# 717 household_images/images/IMG_0292.jpg
# 718 household_images/images/IMG_0397.jpg
# 719 household_images/images/IMG_0398.jpg
# 720 household_images/images/IMG_0408.jpg
# 721 household_images/images/IMG_0409.jpg
# 722 household_images/images/IMG_0417.jpg
# 723 household_images/images/IMG_0564.jpg
# 724 household_images/images/IMG_0567.jpg
# 725 household_images/images/IMG_0584.jpg
# 726 household_images/images/IMG_0694.jpg
# 727 household_images/images/IMG_0695.jpg
# 728 household_images/images/IMG_0703.jpg
# 729 household_images/images/IMG_0704.jpg
# 730 household_images/images/IMG_0730.jpg
# 731 household_images/images/IMG_0731.jpg
# 732 household_images/images/IMG_0732.jpg
# 733 household_images/images/IMG_0733.jpg
# 734 household_images/images/IMG_0734.jpg
# 735 household_images/images/IMG_0735.jpg
# 736 household_images/images/IMG_0736.jpg
# 737 household_images/images/IMG_0743.jpg
# 738 household_images/images/IMG_1066.jpg
# 739 household_images/images/IMG_1067.jpg
# 740 household_images/images/IMG_0278.jpg
# 741 household_images/images/IMG_0395.jpg
# 742 household_images/images/IMG_0396.jpg
# 743 household_images/images/IMG_0414.jpg
# 744 household_images/images/IMG_0415.jpg
# 745 household_images/images/IMG_0416.jpg
# 746 household_images/images/IMG_0582.jpg
# 747 household_images/images/IMG_0583.jpg
# 748 household_images/images/IMG_0692.jpg
# 749 household_images/images/IMG_0693.jpg
# 750 household_images/images/IMG_0717.jpg
# 751 household_images/images/IMG_0740.jpg
# 752 household_images/images/IMG_0741.jpg
# 753 household_images/images/IMG_0742.jpg
# 754 household_images/images/IMG_1065.jpg
# 755 household_images/images/IMG_1083.jpg
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 1.0
# Score: 1.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# ...
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 1.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 1.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 1.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 1.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 1.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.6666666666666666
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.6666666666666666
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.3333333333333333
# Score: 0.0
# Score: 0.0
# Score: 0.0
# (0.14503311258278126, Any[0.0, 0.0, 0.0, 0.0, 0.333333, 0.333333, 0.0, 0.0, 0.0, 0.333333  …  0.0, 0.0, 0.333333, 0.333333, 0.0, 0.0, 0.333333, 0.0, 0.0, 0.0])

# %% [markdown]
# # VGG19 v2

# %%
using Images, Metalhead, HNSW, DelimitedFiles, Flux.Tracker

function load_and_prepare_image(image_path)
    image = load(image_path);
    
    tile_size = 224
    vertical_tiles = 2
    
    target_height = tile_size * vertical_tiles
    scale_percent = target_height/size(image)[1]
    
    horizontal_tiles = Int(fld(size(image)[2] * scale_percent, tile_size))
    target_width = tile_size * horizontal_tiles
    
    scale_width = Int(floor(scale_percent*size(image)[2]))
    resized_image = imresize(image, (target_height, scale_width))

    margin_left = Int(fld(scale_width - target_width, 2))

    windows = []
    
    for i in 1:vertical_tiles
        for j in 1:horizontal_tiles
            window = view(resized_image, ((i-1)*tile_size+1):(i*tile_size), (margin_left+(j-1)*tile_size+1):(margin_left+j*tile_size))
            #println(size(window))
            push!(windows, window)
        end
    end

    return windows
end
    
function convert_window(window)
    img = permutedims(Float32.(channelview(window)), (3, 2, 1));
#     img[:, :, :] .*= 256.0;
#     img[:, :, :] .-= 128.;
#     img[:, :, :] ./= 128.;
end

function convert_output_(y)
    d = zeros(Float32, 512)

    for i in 1:size(y)[1]
        for j in 1:size(y)[2]
            d += reshape(y[i,j,:], (512,))
        end
    end

    return d /= (size(y)[1] * size(y)[2])
end

function convert_output(y)
    y_ = permutedims(y, (4, 1, 2, 3));
    
    batch_size = size(y_)[1]
    
    d = zeros(Float32, batch_size, 512)
    
    for i in 1:batch_size
        d[i, :] = convert_output_(y_[i, :, :, :])
    end
    
    return d
end

function prep_model_layers()
    model = VGG19()
    return model.layers[1:21]
end

function prepare_image_paths_labels()
    labels_file = "household_images/labels.csv"
    data = DelimitedFiles.readdlm(labels_file, ',', header=true)[1]

    directory_path = "household_images/images"
    image_paths = [joinpath(directory_path, data[y, 1]) for y in 1:size(data)[1]]
    image_labels = [data[y, 2] for y in 1:size(data)[1]]
    
    return image_paths, image_labels
end

function main()
   
    model_layers = prep_model_layers()
    
    image_paths, image_labels = prepare_image_paths_labels()

    image_count = size(image_paths)[1]
    neighbor_count = 3
    
    descriptors = []
    labels = []
    indexes = []

    scores = []
    
    # build a dict of descritor index to image index
    
    window_count = 0
    
    for i in 1:image_count
        
        image_path = image_paths[i]
        
        println(i, " ", image_path)
        
        windows = load_and_prepare_image(image_path)
        
        window_count = size(windows)[1]
        
        batch = zeros(Float32, 224, 224, 3, window_count)
        
        for j in 1:window_count
            batch[:,:,:,j] = convert_window(windows[j])
        end
        
        #batch[:,:,:,1] = rand(Float64, 224, 224, 3)

        y = model_layers(batch)
        des = convert_output(y)

        for j in 1:window_count
            push!(descriptors, des[j, :])
            push!(labels, image_labels[i])
            push!(indexes, i)
        end
    
    end
    
    hnsw = HierarchicalNSW(descriptors; efConstruction=100, M=16, ef=50)
    add_to_graph!(hnsw)
    
    # for each descriptor find neighbors, enouph to usually include all candidates
    for i in 1:size(descriptors)[1]
        idxs, dists = knn_search(hnsw, descriptors[i], neighbor_count + window_count)
        
        # find neighbor_count number of candidates and count how many of those belong to the same label
        
        count = 0
        candidates = 0
        
        for j in 1:size(idxs)[1]
            idx = idxs[j]
            
            # if neighbor belongs to same picture, it is not a candidate
            if indexes[i] == indexes[idx]
                continue
            end
            
            # this is a candidate
            
            candidates += 1
            
            # if neighbor has same label
            
            if labels[i] == labels[idx]
                count += 1
            end
            
            if candidates >= neighbor_count
                break
            end
        end
        
        println("Score: ", count/candidates)
        
        push!(scores, count/candidates)
        
    end
    
    return sum(scores)/size(scores)[1], scores
end

main()
